# %%
import glob
import numpy as np
def load_dataset():
    X_train,Y_train,X_test,Y_test = [],[],[],[]
    for f in glob.iglob("./Apple Braeburn/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(0)
    for f in glob.iglob("../test/Apple Braeburn/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(0)   

    for f in glob.iglob("../Apple Golden 1/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(1)
    for f in glob.iglob("../test/Apple Golden 1/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(1)

    for f in glob.iglob("../Apple Golden 2/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(2)
    for f in glob.iglob("../test/Apple Golden 2/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(2)

    for f in glob.iglob("../Apple Golden 3/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(3)
    for f in glob.iglob("../test/Apple Golden 3/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(3)

    for f in glob.iglob("../Apple Granny Smith/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(4)
    for f in glob.iglob("../test/Apple Granny Smith/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(4)

    for f in glob.iglob("../Apple Red 1/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(5)
    for f in glob.iglob("../test/Apple Red 1/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(5)
        
    for f in glob.iglob("../Apple Red 2/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(6)
    for f in glob.iglob("../test/Apple Red 2/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(6)
        
    for f in glob.iglob("../Apple Red 3/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(7)
    for f in glob.iglob("../test/Apple Red 3/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(7)
        
    for f in glob.iglob("../Apple Red Delicious/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(8)
    for f in glob.iglob("../test/Apple Red Delicious/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(8)
        
    for f in glob.iglob("../Apple Red Yellow/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(9)
    for f in glob.iglob("../test/Apple Red Yellow/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(9)
        
    for f in glob.iglob("../Apricot/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(10)
    for f in glob.iglob("../test/Apricot/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(10)
        
    for f in glob.iglob("../Avocado/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(11)
    for f in glob.iglob("../test/Avocado/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(11)
        
    for f in glob.iglob("../Avocado ripe/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(12)
    for f in glob.iglob("../test/Avocado ripe/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(12)
        
    for f in glob.iglob("../Banana/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(13)
    for f in glob.iglob("../test/Banana/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(13)

    for f in glob.iglob("../Banana Red/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(14)
    for f in glob.iglob("../test/Banana Red/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(14)
        
    for f in glob.iglob("../Cactus fruit/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(15)
    for f in glob.iglob("../test/Cactus fruit/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(15)
        
    for f in glob.iglob("../Cantaloupe 1/*"):
        X_train.append(np.asarray(Image.open(f)))
        Y_train.append(16)
    for f in glob.iglob("../test/Cantaloupe 1/*"):
        X_test.append(np.asarray(Image.open(f)))
        Y_test.append(16)
    return X_train,Y_train,X_test,Y_test

# %%
load_dataset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-960ac791287a> in <module>()
# ----> 1 load_dataset()
#
# <ipython-input-12-c2465bf079ba> in load_dataset()
#       4     X_train,Y_train,X_test,Y_test = [],[],[],[]
#       5     for f in glob.iglob("./Apple Braeburn/*"):
# ----> 6         X_train.append(np.asarray(Image.open(f)))
#       7         Y_train.append(0)
#       8     for f in glob.iglob("../test/Apple Braeburn/*"):
#
# NameError: name 'Image' is not defined
